# %%
import pandas as pd

# %%
df = pd.read_csv('london_weather.csv')

# %%
df
# Out:
#       Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 0              1  1996-06-30               NaN               NaN
# 1              2  1996-07-01              19.0              11.0
# 2              3  1996-07-02              20.0              10.0
# 3              4  1996-07-03              19.0              12.0
# 4              5  1996-07-04              19.0              12.0
# ...          ...         ...               ...               ...
# 1378        1383  2000-06-26               NaN              13.0
# 1379        1384  2000-06-27              22.0              11.0
# 1380        1385  2000-06-28              21.0              13.0
# 1381        1386  2000-06-29              20.0              14.0
# 1382        1387  2000-06-30              20.0              14.0
#
#       Max.Gust.SpeedKPH             Events  Season
# 0                   NaN                NaN  Summer
# 1                  28.0               Rain  Summer
# 2                   NaN                NaN  Summer
# 3                   NaN               Rain  Summer
# 4                  25.0               Rain  Summer
# ...                 ...                ...     ...
# 1378                NaN               Rain  Summer
# 1379                NaN                NaN  Summer
# 1380                NaN                NaN  Summer
# 1381                NaN  Rain-Thunderstorm  Summer
# 1382                NaN               Rain  Summer
#
# [1383 rows x 7 columns]

# %%
df.head()
# Out:
#    Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 0           1  1996-06-30               NaN               NaN
# 1           2  1996-07-01              19.0              11.0
# 2           3  1996-07-02              20.0              10.0
# 3           4  1996-07-03              19.0              12.0
# 4           5  1996-07-04              19.0              12.0
#
#    Max.Gust.SpeedKPH Events  Season
# 0                NaN    NaN  Summer
# 1               28.0   Rain  Summer
# 2                NaN    NaN  Summer
# 3                NaN   Rain  Summer
# 4               25.0   Rain  Summer

# %%
df.tail()
# Out:
#       Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 1378        1383  2000-06-26               NaN              13.0
# 1379        1384  2000-06-27              22.0              11.0
# 1380        1385  2000-06-28              21.0              13.0
# 1381        1386  2000-06-29              20.0              14.0
# 1382        1387  2000-06-30              20.0              14.0
#
#       Max.Gust.SpeedKPH             Events  Season
# 1378                NaN               Rain  Summer
# 1379                NaN                NaN  Summer
# 1380                NaN                NaN  Summer
# 1381                NaN  Rain-Thunderstorm  Summer
# 1382                NaN               Rain  Summer

# %%
len(df.index)
# Out:
# 1383

# %%
rainy_days = df['Date'][df['Events'] == 'Rain']

# %%
len(rainy_days)
# Out:
# 688

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use('Solarize_Light2')
df['Max.TemperatureC'].plot()
plt.show()

# %%
df
# Out:
#       Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 0              1  1996-06-30               NaN               NaN
# 1              2  1996-07-01              19.0              11.0
# 2              3  1996-07-02              20.0              10.0
# 3              4  1996-07-03              19.0              12.0
# 4              5  1996-07-04              19.0              12.0
# ...          ...         ...               ...               ...
# 1378        1383  2000-06-26               NaN              13.0
# 1379        1384  2000-06-27              22.0              11.0
# 1380        1385  2000-06-28              21.0              13.0
# 1381        1386  2000-06-29              20.0              14.0
# 1382        1387  2000-06-30              20.0              14.0
#
#       Max.Gust.SpeedKPH             Events  Season
# 0                   NaN                NaN  Summer
# 1                  28.0               Rain  Summer
# 2                   NaN                NaN  Summer
# 3                   NaN               Rain  Summer
# 4                  25.0               Rain  Summer
# ...                 ...                ...     ...
# 1378                NaN               Rain  Summer
# 1379                NaN                NaN  Summer
# 1380                NaN                NaN  Summer
# 1381                NaN  Rain-Thunderstorm  Summer
# 1382                NaN               Rain  Summer
#
# [1383 rows x 7 columns]

# %%
df['Max.TemperatureC'].fillna(df['Max.TemperatureC'].mean(), inplace=True)

# %%
df
# Out:
#       Unnamed: 0        Date  Max.TemperatureC  Min.TemperatureC  \
# 0              1  1996-06-30         15.505102               NaN
# 1              2  1996-07-01         19.000000              11.0
# 2              3  1996-07-02         20.000000              10.0
# 3              4  1996-07-03         19.000000              12.0
# 4              5  1996-07-04         19.000000              12.0
# ...          ...         ...               ...               ...
# 1378        1383  2000-06-26         15.505102              13.0
# 1379        1384  2000-06-27         22.000000              11.0
# 1380        1385  2000-06-28         21.000000              13.0
# 1381        1386  2000-06-29         20.000000              14.0
# 1382        1387  2000-06-30         20.000000              14.0
#
#       Max.Gust.SpeedKPH             Events  Season
# 0                   NaN                NaN  Summer
# 1                  28.0               Rain  Summer
# 2                   NaN                NaN  Summer
# 3                   NaN               Rain  Summer
# 4                  25.0               Rain  Summer
# ...                 ...                ...     ...
# 1378                NaN               Rain  Summer
# 1379                NaN                NaN  Summer
# 1380                NaN                NaN  Summer
# 1381                NaN  Rain-Thunderstorm  Summer
# 1382                NaN               Rain  Summer
#
# [1383 rows x 7 columns]

# %%
import json
import requests
from pprint import pprint
url = 'http://api.openweathermap.org/data/2.5/forecast'
paramDict = {'q' : 'London,UK', 'units' : 'metric', 'appid' : 'b9b95dba596c5a05348ae7c27b6bc33b', 'cnt' : 5}

# %%
response = requests.get(url, params=paramDict)
parsed_json = response.json()
pprint(parsed_json)
# Out:
# {'city': {'coord': {'lat': 51.5085, 'lon': -0.1258},
#           'country': 'GB',
#           'id': 2643743,
#           'name': 'London',
#           'population': 1000000,
#           'sunrise': 1573542764,
#           'sunset': 1573575397,
#           'timezone': 0},
#  'cnt': 5,
#  'cod': '200',
#  'list': [{'clouds': {'all': 100},
#            'dt': 1573570800,
#            'dt_txt': '2019-11-12 15:00:00',
#            'main': {'grnd_level': 993,
#                     'humidity': 77,
#                     'pressure': 997,
#                     'sea_level': 997,
#                     'temp': 6.53,
#                     'temp_kf': -0.34,
#                     'temp_max': 6.87,
#                     'temp_min': 6.53},
#            'rain': {'3h': 0.5},
#            'sys': {'pod': 'd'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 257, 'speed': 6.66}},
#           {'clouds': {'all': 98},
#            'dt': 1573581600,
#            'dt_txt': '2019-11-12 18:00:00',
#            'main': {'grnd_level': 995,
#                     'humidity': 75,
#                     'pressure': 999,
#                     'sea_level': 999,
#                     'temp': 7.67,
#                     'temp_kf': -0.26,
#                     'temp_max': 7.92,
#                     'temp_min': 7.67},
#            'rain': {'3h': 0.69},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 290, 'speed': 4.73}},
#           {'clouds': {'all': 46},
#            'dt': 1573592400,
#            'dt_txt': '2019-11-12 21:00:00',
#            'main': {'grnd_level': 996,
#                     'humidity': 83,
#                     'pressure': 1000,
#                     'sea_level': 1000,
#                     'temp': 6.51,
#                     'temp_kf': -0.17,
#                     'temp_max': 6.68,
#                     'temp_min': 6.51},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 281, 'speed': 3.69}},
#           {'clouds': {'all': 23},
#            'dt': 1573603200,
#            'dt_txt': '2019-11-13 00:00:00',
#            'main': {'grnd_level': 997,
#                     'humidity': 83,
#                     'pressure': 1001,
#                     'sea_level': 1001,
#                     'temp': 5.76,
#                     'temp_kf': -0.09,
#                     'temp_max': 5.84,
#                     'temp_min': 5.76},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'few clouds',
#                         'icon': '02n',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 282, 'speed': 2.99}},
#           {'clouds': {'all': 0},
#            'dt': 1573614000,
#            'dt_txt': '2019-11-13 03:00:00',
#            'main': {'grnd_level': 997,
#                     'humidity': 86,
#                     'pressure': 1001,
#                     'sea_level': 1001,
#                     'temp': 5.08,
#                     'temp_kf': 0,
#                     'temp_max': 5.08,
#                     'temp_min': 5.08},
#            'sys': {'pod': 'n'},
#            'weather': [{'description': 'clear sky',
#                         'icon': '01n',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 261, 'speed': 2.29}}],
#  'message': 0}

# %%
from pandas.io.json import json_normalize

# %%
df = json_normalize(parsed_json['list'])
df
# Out:
#            dt                                            weather  \
# 0  1573570800  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 1  1573581600  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 2  1573592400  [{'id': 802, 'main': 'Clouds', 'description': ...
# 3  1573603200  [{'id': 801, 'main': 'Clouds', 'description': ...
# 4  1573614000  [{'id': 800, 'main': 'Clear', 'description': '...
#
#                 dt_txt  main.temp  main.temp_min  main.temp_max  \
# 0  2019-11-12 15:00:00       6.53           6.53           6.87
# 1  2019-11-12 18:00:00       7.67           7.67           7.92
# 2  2019-11-12 21:00:00       6.51           6.51           6.68
# 3  2019-11-13 00:00:00       5.76           5.76           5.84
# 4  2019-11-13 03:00:00       5.08           5.08           5.08
#
#    main.pressure  main.sea_level  main.grnd_level  main.humidity  \
# 0            997             997              993             77
# 1            999             999              995             75
# 2           1000            1000              996             83
# 3           1001            1001              997             83
# 4           1001            1001              997             86
#
#    main.temp_kf  clouds.all  wind.speed  wind.deg  rain.3h sys.pod
# 0         -0.34         100        6.66       257     0.50       d
# 1         -0.26          98        4.73       290     0.69       n
# 2         -0.17          46        3.69       281      NaN       n
# 3         -0.09          23        2.99       282      NaN       n
# 4          0.00           0        2.29       261      NaN       n

# %%
max = df['main.temp_max'].max()
max
# Out:
# 7.92
